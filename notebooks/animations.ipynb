# %%
#Saving an animation of daily precipitation

# %%
#importing modules and data

import imp
imp.load_source('StatFns', "/glade/u/home/kwheelan/scripts/StatFns.py")
from StatFns import *
imp.load_source('DataFns', "/glade/u/home/kwheelan/scripts/DataFns.py")
from DataFns import *

import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import xarray as xr
# Out:
# /gpfs/u/apps/dav/opt/python/3.6.8/gnu/7.3.0/pkg-library/20190326/lib/python3.6/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
#the data to animate
unetPreds =xr.open_dataset('/glade/work/kwheelan/datasets/predictions/unet/unet_1993_preds_run5.nc')
year = 1993
data = unetPreds.sel(time = slice('1993-01-01','1993-12-31'))

# %%
#making and saving the animation
#arguments are: dataset, column name 1 (Prcp = observations), column name 2 (preds are unet preds), where to save the animation)
makeDoubleAnim(unetPreds,'Prcp', 'preds', filePath = "/glade/scratch/kwheelan/animations/ObsUnet_sidebyside.mp4")
